# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
import torchvision.transforms as T
import torchvision.models as models
import matplotlib.pyplot as plt
from IPython.display import clear_output
import time
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support
import torch.nn.functional as F
import torch.multiprocessing as mp
import json
import ray

# %%
transform_all = T.Compose([
    T.Resize((224, 224)),   # paksa seragam
    T.ToTensor(),
])

# %%
data_root = "data"   # Ubah sesuai directory Anda
full_dataset = ImageFolder(data_root, transform=transform_all)
num_classes = len(full_dataset.classes)

# split dataset otomatis
train_size = int(0.7 * len(full_dataset))
val_size   = len(full_dataset) - train_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
val_loader   = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4)

# %%
class ResNetBottleneck(nn.Module):
    def __init__(self, in_channels, filters):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, filters, 1)
        self.bn1 = nn.BatchNorm2d(filters)

        self.conv2 = nn.Conv2d(filters, filters, 3, padding=1)
        self.bn2 = nn.BatchNorm2d(filters)

        self.conv3 = nn.Conv2d(filters, filters * 4, 1)
        self.bn3 = nn.BatchNorm2d(filters * 4)

        self.shortcut_needed = (in_channels != filters * 4)
        if self.shortcut_needed:
            self.shortcut_conv = nn.Conv2d(in_channels, filters * 4, 1)

    def forward(self, x):
        shortcut = x
        if self.shortcut_needed:
            shortcut = self.shortcut_conv(x)

        x = torch.relu(self.bn1(self.conv1(x)))
        x = torch.relu(self.bn2(self.conv2(x)))
        x = self.bn3(self.conv3(x))

        return torch.relu(x + shortcut)


class HybridEfficientNet(nn.Module):
    def __init__(self, num_classes=4, dropoout=0.3):
        super().__init__()

        # Load pretrained EfficientNet-B0
        self.base = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)

        # Freeze feature extractor
        self.base.features.requires_grad_(False)

        #in_channels = 1280  # output EfficientNetB0 channels
        in_channels = self.base.features[-1].out_channels

        self.b1 = ResNetBottleneck(in_channels, 64)
        self.b2 = ResNetBottleneck(64 * 4, 64)

        self.pool = nn.AdaptiveAvgPool2d(1)
        self.dropout = nn.Dropout(dropoout)
        self.fc = nn.Linear(64 * 4, num_classes)

    def forward(self, x):
        x = self.base.features(x)
        x = self.b1(x)
        x = self.b2(x)
        x = self.pool(x)
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        return self.fc(x)

class HybridMobileNet(nn.Module):
    def __init__(self, num_classes=4, dropout=0.3):
        super().__init__()

        self.base = models.mobilenet_v3_small(
            weights=models.MobileNet_V3_Small_Weights.IMAGENET1K_V1
        )

        self.base.features.requires_grad_(False)

        # ambil channel output terakhir
        in_channels = self.base.features[-1].out_channels  # = 576

        self.b1 = ResNetBottleneck(in_channels, 64)   # 576 → 256
        self.b2 = ResNetBottleneck(64 * 4, 64)        # 256 → 256

        self.pool = nn.AdaptiveAvgPool2d(1)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(64 * 4, num_classes)      # 256 → num_classes

    def forward(self, x):
        x = self.base.features(x)
        x = self.b1(x)
        x = self.b2(x)
        x = self.pool(x)
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        return self.fc(x)

# %%
def train_model(device, model, optimizer, name="model", scheduler=False, epochs=10):
    criterion = nn.CrossEntropyLoss()
    
    scheduler_optimizer = None
    if scheduler:
        scheduler_optimizer = torch.optim.lr_scheduler.CosineAnnealingLR(
            optimizer, T_max=epochs
        )
    
    start_time = time.perf_counter()

    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        correct = 0
        total = 0

        for imgs, labels in train_loader:
            imgs, labels = imgs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        avg_train_loss = running_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        train_accs.append(correct / total)

        model.eval()
        val_running_loss = 0
        correct = 0
        total = 0

        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs, labels = imgs.to(device), labels.to(device)
                outputs = model(imgs)

                loss = criterion(outputs, labels)
                val_running_loss += loss.item()

                _, preds = torch.max(outputs, 1)
                correct += (preds == labels).sum().item()
                total += labels.size(0)

        avg_val_loss = val_running_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        val_accs.append(correct / total)

        if scheduler_optimizer is not None:
            scheduler_optimizer.step() 

        print(f"[{name}] Epoch {epoch+1}/{epochs}")
        print(f"  Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
        print(f"  Train Acc : {train_accs[-1]:.4f} | Val Acc : {val_accs[-1]:.4f}")

        clear_output(wait=True)

        fig, ax = plt.subplots(1, 2, figsize=(12, 5))

        # Loss panel
        ax[0].plot(train_losses, label="Train Loss")
        ax[0].plot(val_losses, label="Val Loss")
        ax[0].set_title("Training & Validation Loss")
        ax[0].legend()

        # Acc panel
        ax[1].plot(train_accs, label="Train Acc")
        ax[1].plot(val_accs, label="Val Acc")
        ax[1].set_title("Training & Validation Accuracy")
        ax[1].legend()

        plt.tight_layout()
        display(fig)
        plt.close(fig)

    end_time = time.perf_counter()
    elapsed_time = end_time - start_time
    return train_losses, val_losses, train_accs, val_accs, elapsed_time

def Summary(name, epoch, train_losses, val_losses, train_accs, val_accs, elapsed_time):
    print()
    print(f"[{name}]")
    print(f"  Total Epochs: {epoch}")
    print(f"  Train Loss: {np.average(train_losses):.4f} | Val Loss: {np.average(val_losses):.4f}")
    print(f"  Train Acc : {train_accs[-1]:.4f} | Val Acc : {val_accs[-1]:.4f}")
    print(f"  Time : {elapsed_time:.4f}s ~ {(elapsed_time / 60):.4f}m")

from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support
import torch

import matplotlib.pyplot as plt
import numpy as np

def plot_confusion_matrix(cm, class_names, figsize=(8,6)):
    plt.figure(figsize=figsize)
    plt.imshow(cm, interpolation='nearest')
    plt.title("Confusion Matrix")
    plt.colorbar()

    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    # Label angka di kotak
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'),
                     horizontalalignment="center",
                     color="black" if cm[i, j] > thresh else "white")

    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.tight_layout()
    plt.show()

def classification_report_df(y_true, y_pred, class_names):
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)
    df = pd.DataFrame(report).transpose()
    return df

def evaluate_model(model, dataloader, device, class_names):
    start_time = time.perf_counter()
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    end_time = time.perf_counter()
    elapsed_time = end_time - start_time
    cm = confusion_matrix(all_labels, all_preds)

    return {
        "confusion_matrix": cm,
        "preds": all_preds,
        "labels": all_labels,
        "time": elapsed_time
    }

def clean_gpu():
    for var in list(globals().keys()):
        if isinstance(globals()[var], torch.Tensor):
            del globals()[var]

    import gc
    gc.collect()
    torch.cuda.synchronize()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()

# %%
# Hyperparameter bounds
LR_MIN, LR_MAX = 0.003134621711988863, 0.004174003510706967
WD_MIN, WD_MAX = 0.0002606683474969785, 0.0009743301033360753
DP_MIN, DP_MAX = 0.21222920791578329, 0.4609636959573514

#global name, model
name = "mobresnet"
#model = HybridMobileNet(num_classes=4)

# %%
ray.init(ignore_reinit_error=True)
from IPython.display import display

@ray.remote(num_gpus=1)
def train_remote(params):
    #def display(*args, **kwargs):
    #    pass
        
    lr, wd, dp = params

    # Inisialisasi model di worker
    model = HybridMobileNet(num_classes=4)
    device = torch.device("cuda")

    model.dropout.p = dp
    model = model.to(device)

    lr = abs(lr)
    wd = abs(wd)
    dp = abs(dp)
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=wd)

    train_losses, val_losses, train_accs, val_accs, _ = train_model(
        device, model, optimizer, name=name, scheduler=True, epochs=10
    )

    fitness = val_accs[-1]

    torch.save(model.state_dict(), "./ga/" + name + "-" + str(fitness) + ".pth")

    del model
    del optimizer
    clean_gpu()

    return fitness
# Out:
# 2025-12-10 17:52:12,600	INFO worker.py:2023 -- Started a local Ray instance.
# C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\ray\_private\worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# (pid=gcs_server) [2025-12-10 17:52:42,292 E 10956 1644] (gcs_server.exe) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2025-12-10 17:52:44,675 E 25940 22368] (raylet.exe) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (train_remote pid=10824) [mobresnet] Epoch 1/10
# (train_remote pid=10824)   Train Loss: 0.3127 | Val Loss: 0.3751
# (train_remote pid=10824)   Train Acc : 0.8825 | Val Acc : 0.8550
# m(train_remote pid=10824)
# m(train_remote pid=8360)
# (train_remote pid=10824) Figure(1200x500)
# (train_remote pid=8360) Figure(1200x500)
# m(train_remote pid=8360)
# (train_remote pid=8360) [mobresnet] Epoch 2/10 [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (train_remote pid=8360)   Train Loss: 0.1545 | Val Loss: 0.6195 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Acc : 0.9450 | Val Acc : 0.7940 [repeated 2x across cluster]
# (train_remote pid=8360) Figure(1200x500)
# m(train_remote pid=10824)
# (train_remote pid=10824) Figure(1200x500)
# m(train_remote pid=8360)
# (train_remote pid=8360) [mobresnet] Epoch 3/10 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Loss: 0.1379 | Val Loss: 0.2983 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Acc : 0.9492 | Val Acc : 0.8846 [repeated 2x across cluster]
# (train_remote pid=8360) Figure(1200x500)
# m(train_remote pid=10824)
# (train_remote pid=10824) Figure(1200x500)
# m(train_remote pid=8360)
# (train_remote pid=8360) [mobresnet] Epoch 4/10 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Loss: 0.1018 | Val Loss: 0.2594 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Acc : 0.9648 | Val Acc : 0.9013 [repeated 2x across cluster]
# (train_remote pid=8360) Figure(1200x500)
# m(train_remote pid=10824)
# (train_remote pid=10824) Figure(1200x500)
# m(train_remote pid=8360)
# (train_remote pid=8360) [mobresnet] Epoch 5/10 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Loss: 0.0642 | Val Loss: 0.1455 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Acc : 0.9772 | Val Acc : 0.9451 [repeated 2x across cluster]
# (train_remote pid=8360) Figure(1200x500)
# m(train_remote pid=10824)
# (train_remote pid=10824) Figure(1200x500)
# m(train_remote pid=8360)
# (train_remote pid=8360) [mobresnet] Epoch 6/10 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Loss: 0.0543 | Val Loss: 0.1241 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Acc : 0.9868 | Val Acc : 0.9531 [repeated 2x across cluster]
# (train_remote pid=8360) Figure(1200x500)
# m(train_remote pid=10824)
# (train_remote pid=10824) Figure(1200x500)
# m(train_remote pid=8360)
# (train_remote pid=8360) [mobresnet] Epoch 7/10 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Loss: 0.0588 | Val Loss: 0.1204 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Acc : 0.9836 | Val Acc : 0.9574 [repeated 2x across cluster]
# (train_remote pid=8360) Figure(1200x500)
# m(train_remote pid=10824)
# (train_remote pid=10824) Figure(1200x500)
# m(train_remote pid=8360)
# (train_remote pid=8360) [mobresnet] Epoch 8/10 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Loss: 0.0335 | Val Loss: 0.0783 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Acc : 0.9910 | Val Acc : 0.9710 [repeated 2x across cluster]
# (train_remote pid=8360) Figure(1200x500)
# m(train_remote pid=10824)
# (train_remote pid=10824) Figure(1200x500)
# m(train_remote pid=8360)
# (train_remote pid=8360) [mobresnet] Epoch 9/10 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Loss: 0.0335 | Val Loss: 0.0683 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Acc : 0.9923 | Val Acc : 0.9741 [repeated 2x across cluster]
# (train_remote pid=8360) Figure(1200x500)
# m(train_remote pid=10824)
# (train_remote pid=10824) Figure(1200x500)
# m(train_remote pid=8360)
# (train_remote pid=8360) [mobresnet] Epoch 10/10 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Loss: 0.0221 | Val Loss: 0.0706 [repeated 2x across cluster]
# (train_remote pid=8360)   Train Acc : 0.9950 | Val Acc : 0.9753 [repeated 2x across cluster]
# m(train_remote pid=10824)
# (train_remote pid=8360) Figure(1200x500)
# (train_remote pid=10824) Figure(1200x500)
# m(train_remote pid=5752)
# (train_remote pid=5752) [mobresnet] Epoch 1/10 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Loss: 0.3462 | Val Loss: 0.2650 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Acc : 0.8862 | Val Acc : 0.9031 [repeated 2x across cluster]
# m(train_remote pid=27256)
# (train_remote pid=5752) Figure(1200x500)
# (train_remote pid=27256) Figure(1200x500)
# m(train_remote pid=5752)
# (train_remote pid=5752) [mobresnet] Epoch 2/10 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Loss: 0.1787 | Val Loss: 0.4581 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Acc : 0.9373 | Val Acc : 0.8118 [repeated 2x across cluster]
# (train_remote pid=5752) Figure(1200x500)
# m(train_remote pid=27256)
# (train_remote pid=27256) Figure(1200x500)
# m(train_remote pid=5752)
# (train_remote pid=5752) [mobresnet] Epoch 3/10 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Loss: 0.1245 | Val Loss: 0.3202 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Acc : 0.9526 | Val Acc : 0.8692 [repeated 2x across cluster]
# (train_remote pid=5752) Figure(1200x500)
# m(train_remote pid=27256)
# (train_remote pid=27256) Figure(1200x500)
# m(train_remote pid=5752)
# (train_remote pid=5752) [mobresnet] Epoch 4/10 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Loss: 0.1033 | Val Loss: 0.5453 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Acc : 0.9643 | Val Acc : 0.7890 [repeated 2x across cluster]
# (train_remote pid=5752) Figure(1200x500)
# m(train_remote pid=27256)
# (train_remote pid=27256) Figure(1200x500)
# m(train_remote pid=5752)
# (train_remote pid=5752) [mobresnet] Epoch 5/10 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Loss: 0.0649 | Val Loss: 0.1493 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Acc : 0.9804 | Val Acc : 0.9476 [repeated 2x across cluster]
# m(train_remote pid=27256)
# (train_remote pid=5752) Figure(1200x500)
# (train_remote pid=27256) Figure(1200x500)
# m(train_remote pid=5752)
# (train_remote pid=5752) [mobresnet] Epoch 6/10 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Loss: 0.0615 | Val Loss: 0.0816 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Acc : 0.9775 | Val Acc : 0.9729 [repeated 2x across cluster]
# (train_remote pid=5752) Figure(1200x500)
# m(train_remote pid=27256)
# (train_remote pid=27256) Figure(1200x500)
# m(train_remote pid=5752)
# (train_remote pid=5752) [mobresnet] Epoch 7/10 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Loss: 0.0349 | Val Loss: 0.1277 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Acc : 0.9876 | Val Acc : 0.9630 [repeated 2x across cluster]
# (train_remote pid=5752) Figure(1200x500)
# m(train_remote pid=27256)
# (train_remote pid=27256) Figure(1200x500)
# m(train_remote pid=5752)
# (train_remote pid=5752) [mobresnet] Epoch 8/10 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Loss: 0.0236 | Val Loss: 0.0684 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Acc : 0.9929 | Val Acc : 0.9741 [repeated 2x across cluster]
# (train_remote pid=5752) Figure(1200x500)
# m(train_remote pid=27256)
# (train_remote pid=27256) Figure(1200x500)
# m(train_remote pid=5752)
# (train_remote pid=5752) [mobresnet] Epoch 9/10 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Loss: 0.0160 | Val Loss: 0.0768 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Acc : 0.9950 | Val Acc : 0.9729 [repeated 2x across cluster]
# (train_remote pid=5752) Figure(1200x500)
# m(train_remote pid=27256)
# (train_remote pid=27256) Figure(1200x500)
# m(train_remote pid=5752)
# (train_remote pid=5752) [mobresnet] Epoch 10/10 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Loss: 0.0182 | Val Loss: 0.0734 [repeated 2x across cluster]
# (train_remote pid=5752)   Train Acc : 0.9942 | Val Acc : 0.9735 [repeated 2x across cluster]
# (train_remote pid=5752) Figure(1200x500)
# m(train_remote pid=27256)
# (train_remote pid=27256) Figure(1200x500)
# m(train_remote pid=26052)
# (train_remote pid=26052) [mobresnet] Epoch 1/10 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Loss: 0.3000 | Val Loss: 0.2475 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Acc : 0.8841 | Val Acc : 0.9192 [repeated 2x across cluster]
# (train_remote pid=26052) Figure(1200x500)
# m(train_remote pid=18864)
# (train_remote pid=18864) Figure(1200x500)
# m(train_remote pid=26052)
# (train_remote pid=26052) [mobresnet] Epoch 2/10 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Loss: 0.1556 | Val Loss: 0.3650 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Acc : 0.9508 | Val Acc : 0.8550 [repeated 2x across cluster]
# (train_remote pid=26052) Figure(1200x500)
# m(train_remote pid=18864)
# (train_remote pid=18864) Figure(1200x500)
# m(train_remote pid=26052)
# (train_remote pid=26052) [mobresnet] Epoch 3/10 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Loss: 0.1009 | Val Loss: 0.2393 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Acc : 0.9643 | Val Acc : 0.9143 [repeated 2x across cluster]
# (train_remote pid=26052) Figure(1200x500)
# m(train_remote pid=18864)
# (train_remote pid=18864) Figure(1200x500)
# m(train_remote pid=26052)
# (train_remote pid=26052) [mobresnet] Epoch 4/10 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Loss: 0.0876 | Val Loss: 0.6288 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Acc : 0.9714 | Val Acc : 0.7773 [repeated 2x across cluster]
# (train_remote pid=26052) Figure(1200x500)
# m(train_remote pid=18864)
# (train_remote pid=18864) Figure(1200x500)
# m(train_remote pid=26052)
# (train_remote pid=26052) [mobresnet] Epoch 5/10 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Loss: 0.0715 | Val Loss: 0.1981 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Acc : 0.9735 | Val Acc : 0.9254 [repeated 2x across cluster]
# (train_remote pid=26052) Figure(1200x500)
# m(train_remote pid=18864)
# (train_remote pid=18864) Figure(1200x500)
# (train_remote pid=18864) [mobresnet] Epoch 5/10
# (train_remote pid=18864)   Train Loss: 0.0656 | Val Loss: 0.1015
# (train_remote pid=18864)   Train Acc : 0.9751 | Val Acc : 0.9679
# (train_remote pid=26052) [mobresnet] Epoch 6/10
# (train_remote pid=26052)   Train Loss: 0.0425 | Val Loss: 0.1552
# (train_remote pid=26052)   Train Acc : 0.9870 | Val Acc : 0.9389
# m(train_remote pid=26052)
# (train_remote pid=26052) Figure(1200x500)
# m(train_remote pid=18864)
# (train_remote pid=18864) Figure(1200x500)
# m(train_remote pid=26052)
# (train_remote pid=26052) [mobresnet] Epoch 7/10 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Loss: 0.0393 | Val Loss: 0.0709 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Acc : 0.9862 | Val Acc : 0.9741 [repeated 2x across cluster]
# (train_remote pid=26052) Figure(1200x500)
# m(train_remote pid=18864)
# (train_remote pid=18864) Figure(1200x500)
# m(train_remote pid=26052)
# (train_remote pid=26052) [mobresnet] Epoch 8/10 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Loss: 0.0186 | Val Loss: 0.0665 [repeated 2x across cluster]
# (train_remote pid=26052)   Train Acc : 0.9952 | Val Acc : 0.9784 [repeated 2x across cluster]
# (train_remote pid=26052) Figure(1200x500)
# m(train_remote pid=18864)
# (train_remote pid=18864) [mobresnet] Epoch 8/10
# (train_remote pid=18864)   Train Loss: 0.0225 | Val Loss: 0.0775
# (train_remote pid=18864)   Train Acc : 0.9923 | Val Acc : 0.9747
# (train_remote pid=18864) Figure(1200x500)
# (train_remote pid=26052) [mobresnet] Epoch 9/10
# (train_remote pid=26052)   Train Loss: 0.0151 | Val Loss: 0.0670
# (train_remote pid=26052)   Train Acc : 0.9952 | Val Acc : 0.9778
# m(train_remote pid=26052)
# (train_remote pid=26052) Figure(1200x500)
# m(train_remote pid=18864)
# (train_remote pid=18864) Figure(1200x500)
# (train_remote pid=18864) [mobresnet] Epoch 9/10
# (train_remote pid=18864)   Train Loss: 0.0185 | Val Loss: 0.0789
# (train_remote pid=18864)   Train Acc : 0.9939 | Val Acc : 0.9741
# (train_remote pid=26052) [mobresnet] Epoch 10/10
# (train_remote pid=26052)   Train Loss: 0.0141 | Val Loss: 0.0662
# (train_remote pid=26052)   Train Acc : 0.9963 | Val Acc : 0.9796
# m(train_remote pid=26052)
# (train_remote pid=26052) Figure(1200x500)
# m(train_remote pid=18864)
# (train_remote pid=18864) [mobresnet] Epoch 10/10
# (train_remote pid=18864)   Train Loss: 0.0200 | Val Loss: 0.0731
# (train_remote pid=18864)   Train Acc : 0.9926 | Val Acc : 0.9766
# (train_remote pid=18864) Figure(1200x500)
# (train_remote pid=21532) [mobresnet] Epoch 1/10
# (train_remote pid=21532)   Train Loss: 0.3071 | Val Loss: 0.4108
# (train_remote pid=21532)   Train Acc : 0.8831 | Val Acc : 0.8341
# m(train_remote pid=21532)
# m(train_remote pid=6912)
# (train_remote pid=21532) Figure(1200x500)
# (train_remote pid=6912) Figure(1200x500)
# m(train_remote pid=21532)
# (train_remote pid=21532) [mobresnet] Epoch 2/10 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Loss: 0.1863 | Val Loss: 0.3920 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Acc : 0.9402 | Val Acc : 0.8513 [repeated 2x across cluster]
# (train_remote pid=21532) Figure(1200x500)
# m(train_remote pid=6912)
# (train_remote pid=6912) Figure(1200x500)
# m(train_remote pid=21532)
# (train_remote pid=21532) [mobresnet] Epoch 3/10 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Loss: 0.1369 | Val Loss: 0.5541 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Acc : 0.9569 | Val Acc : 0.7977 [repeated 2x across cluster]
# (train_remote pid=21532) Figure(1200x500)
# m(train_remote pid=6912)
# (train_remote pid=6912) Figure(1200x500)
# m(train_remote pid=21532)
# (train_remote pid=21532) [mobresnet] Epoch 4/10 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Loss: 0.1030 | Val Loss: 0.2147 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Acc : 0.9656 | Val Acc : 0.9087 [repeated 2x across cluster]
# (train_remote pid=21532) Figure(1200x500)
# m(train_remote pid=6912)
# (train_remote pid=6912) Figure(1200x500)
# m(train_remote pid=21532)
# (train_remote pid=21532) [mobresnet] Epoch 5/10 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Loss: 0.0751 | Val Loss: 0.0915 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Acc : 0.9751 | Val Acc : 0.9661 [repeated 2x across cluster]
# (train_remote pid=21532) Figure(1200x500)
# m(train_remote pid=6912)
# (train_remote pid=6912) Figure(1200x500)
# m(train_remote pid=21532)
# (train_remote pid=21532) [mobresnet] Epoch 6/10 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Loss: 0.0539 | Val Loss: 0.0885 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Acc : 0.9810 | Val Acc : 0.9698 [repeated 2x across cluster]
# (train_remote pid=21532) Figure(1200x500)
# m(train_remote pid=6912)
# (train_remote pid=6912) Figure(1200x500)
# m(train_remote pid=21532)
# (train_remote pid=21532) [mobresnet] Epoch 7/10 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Loss: 0.0374 | Val Loss: 0.0816 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Acc : 0.9886 | Val Acc : 0.9698 [repeated 2x across cluster]
# (train_remote pid=21532) Figure(1200x500)
# m(train_remote pid=6912)
# (train_remote pid=6912) Figure(1200x500)
# m(train_remote pid=21532)
# (train_remote pid=21532) [mobresnet] Epoch 8/10 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Loss: 0.0315 | Val Loss: 0.0975 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Acc : 0.9915 | Val Acc : 0.9685 [repeated 2x across cluster]
# m(train_remote pid=6912)
# (train_remote pid=21532) Figure(1200x500)
# (train_remote pid=6912) Figure(1200x500)
# m(train_remote pid=21532)
# (train_remote pid=21532) [mobresnet] Epoch 9/10 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Loss: 0.0240 | Val Loss: 0.0928 [repeated 2x across cluster]
# (train_remote pid=21532)   Train Acc : 0.9902 | Val Acc : 0.9692 [repeated 2x across cluster]
# m(train_remote pid=6912)
# (train_remote pid=21532) Figure(1200x500)
# (train_remote pid=6912) Figure(1200x500)
# m(train_remote pid=6912)
# (train_remote pid=6912) [mobresnet] Epoch 10/10 [repeated 2x across cluster]
# (train_remote pid=6912)   Train Loss: 0.0682 | Val Loss: 0.0997 [repeated 2x across cluster]
# (train_remote pid=6912)   Train Acc : 0.9862 | Val Acc : 0.9729 [repeated 2x across cluster]
# (train_remote pid=6912) Figure(1200x500)
# m(train_remote pid=21532)
# (train_remote pid=21532) Figure(1200x500)
# m(train_remote pid=24900)
# (train_remote pid=24900) [mobresnet] Epoch 1/10 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Loss: 0.2890 | Val Loss: 0.2645 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Acc : 0.8934 | Val Acc : 0.9050 [repeated 2x across cluster]
# (train_remote pid=24900) Figure(1200x500)
# m(train_remote pid=21384)
# (train_remote pid=21384) Figure(1200x500)
# m(train_remote pid=24900)
# (train_remote pid=24900) [mobresnet] Epoch 2/10 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Loss: 0.1633 | Val Loss: 0.4728 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Acc : 0.9468 | Val Acc : 0.8106 [repeated 2x across cluster]
# (train_remote pid=24900) Figure(1200x500)
# m(train_remote pid=21384)
# (train_remote pid=21384) Figure(1200x500)
# m(train_remote pid=24900)
# (train_remote pid=24900) [mobresnet] Epoch 3/10 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Loss: 0.1109 | Val Loss: 0.3435 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Acc : 0.9619 | Val Acc : 0.8883 [repeated 2x across cluster]
# (train_remote pid=24900) Figure(1200x500)
# m(train_remote pid=21384)
# (train_remote pid=21384) Figure(1200x500)
# m(train_remote pid=24900)
# (train_remote pid=24900) [mobresnet] Epoch 4/10 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Loss: 0.0888 | Val Loss: 0.1751 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Acc : 0.9698 | Val Acc : 0.9389 [repeated 2x across cluster]
# (train_remote pid=24900) Figure(1200x500)
# m(train_remote pid=21384)
# (train_remote pid=21384) Figure(1200x500)
# m(train_remote pid=24900)
# (train_remote pid=24900) [mobresnet] Epoch 5/10 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Loss: 0.0841 | Val Loss: 0.1261 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Acc : 0.9717 | Val Acc : 0.9513 [repeated 2x across cluster]
# (train_remote pid=24900) Figure(1200x500)
# m(train_remote pid=21384)
# (train_remote pid=21384) Figure(1200x500)
# m(train_remote pid=24900)
# (train_remote pid=24900) [mobresnet] Epoch 6/10 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Loss: 0.0514 | Val Loss: 0.1118 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Acc : 0.9833 | Val Acc : 0.9636 [repeated 2x across cluster]
# (train_remote pid=24900) Figure(1200x500)
# m(train_remote pid=21384)
# (train_remote pid=21384) Figure(1200x500)
# m(train_remote pid=24900)
# (train_remote pid=24900) [mobresnet] Epoch 7/10 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Loss: 0.0406 | Val Loss: 0.0995 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Acc : 0.9865 | Val Acc : 0.9673 [repeated 2x across cluster]
# m(train_remote pid=21384)
# (train_remote pid=24900) Figure(1200x500)
# (train_remote pid=21384) Figure(1200x500)
# m(train_remote pid=21384)
# (train_remote pid=21384) [mobresnet] Epoch 8/10 [repeated 2x across cluster]
# (train_remote pid=21384)   Train Loss: 0.0304 | Val Loss: 0.0891 [repeated 2x across cluster]
# (train_remote pid=21384)   Train Acc : 0.9910 | Val Acc : 0.9735 [repeated 2x across cluster]
# m(train_remote pid=24900)
# (train_remote pid=21384) Figure(1200x500)
# (train_remote pid=24900) Figure(1200x500)
# m(train_remote pid=21384)
# (train_remote pid=21384) [mobresnet] Epoch 9/10 [repeated 2x across cluster]
# (train_remote pid=21384)   Train Loss: 0.0263 | Val Loss: 0.0760 [repeated 2x across cluster]
# (train_remote pid=21384)   Train Acc : 0.9926 | Val Acc : 0.9735 [repeated 2x across cluster]
# m(train_remote pid=24900)
# (train_remote pid=21384) Figure(1200x500)
# (train_remote pid=24900) Figure(1200x500)
# m(train_remote pid=24900)
# (train_remote pid=24900) [mobresnet] Epoch 10/10 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Loss: 0.0157 | Val Loss: 0.0717 [repeated 2x across cluster]
# (train_remote pid=24900)   Train Acc : 0.9958 | Val Acc : 0.9741 [repeated 2x across cluster]
# m(train_remote pid=21384)
# (train_remote pid=24900) Figure(1200x500)
# (train_remote pid=21384) Figure(1200x500)
# m(train_remote pid=24176)
# (train_remote pid=24176) [mobresnet] Epoch 1/10 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Loss: 0.3141 | Val Loss: 0.2654 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Acc : 0.8860 | Val Acc : 0.9013 [repeated 2x across cluster]
# (train_remote pid=24176) Figure(1200x500)
# m(train_remote pid=27908)
# (train_remote pid=27908) Figure(1200x500)
# m(train_remote pid=24176)
# (train_remote pid=24176) [mobresnet] Epoch 2/10 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Loss: 0.1552 | Val Loss: 0.7793 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Acc : 0.9431 | Val Acc : 0.7255 [repeated 2x across cluster]
# m(train_remote pid=27908)
# (train_remote pid=24176) Figure(1200x500)
# (train_remote pid=27908) Figure(1200x500)
# m(train_remote pid=24176)
# (train_remote pid=24176) [mobresnet] Epoch 3/10 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Loss: 0.1148 | Val Loss: 0.5703 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Acc : 0.9611 | Val Acc : 0.7927 [repeated 2x across cluster]
# m(train_remote pid=27908)
# (train_remote pid=24176) Figure(1200x500)
# (train_remote pid=27908) Figure(1200x500)
# m(train_remote pid=24176)
# (train_remote pid=24176) [mobresnet] Epoch 4/10 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Loss: 0.0774 | Val Loss: 0.5253 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Acc : 0.9696 | Val Acc : 0.8081 [repeated 2x across cluster]
# (train_remote pid=24176) Figure(1200x500)
# m(train_remote pid=27908)
# (train_remote pid=27908) Figure(1200x500)
# m(train_remote pid=24176)
# (train_remote pid=24176) [mobresnet] Epoch 5/10 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Loss: 0.0863 | Val Loss: 0.1672 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Acc : 0.9738 | Val Acc : 0.9395 [repeated 2x across cluster]
# m(train_remote pid=27908)
# (train_remote pid=24176) Figure(1200x500)
# (train_remote pid=27908) Figure(1200x500)
# m(train_remote pid=24176)
# (train_remote pid=24176) [mobresnet] Epoch 6/10 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Loss: 0.0597 | Val Loss: 0.0998 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Acc : 0.9791 | Val Acc : 0.9611 [repeated 2x across cluster]
# m(train_remote pid=27908)
# (train_remote pid=24176) Figure(1200x500)
# (train_remote pid=27908) Figure(1200x500)
# m(train_remote pid=24176)
# (train_remote pid=24176) [mobresnet] Epoch 7/10 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Loss: 0.0418 | Val Loss: 0.0855 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Acc : 0.9841 | Val Acc : 0.9729 [repeated 2x across cluster]
# m(train_remote pid=27908)
# (train_remote pid=24176) Figure(1200x500)
# (train_remote pid=27908) Figure(1200x500)
# m(train_remote pid=24176)
# (train_remote pid=24176) [mobresnet] Epoch 8/10 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Loss: 0.0302 | Val Loss: 0.0920 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Acc : 0.9913 | Val Acc : 0.9698 [repeated 2x across cluster]
# m(train_remote pid=27908)
# (train_remote pid=24176) Figure(1200x500)
# (train_remote pid=27908) Figure(1200x500)
# m(train_remote pid=24176)
# (train_remote pid=24176) [mobresnet] Epoch 9/10 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Loss: 0.0270 | Val Loss: 0.0843 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Acc : 0.9942 | Val Acc : 0.9741 [repeated 2x across cluster]
# (train_remote pid=24176) Figure(1200x500)
# m(train_remote pid=27908)
# (train_remote pid=27908) Figure(1200x500)
# m(train_remote pid=24176)
# (train_remote pid=24176) [mobresnet] Epoch 10/10 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Loss: 0.0209 | Val Loss: 0.0821 [repeated 2x across cluster]
# (train_remote pid=24176)   Train Acc : 0.9947 | Val Acc : 0.9729 [repeated 2x across cluster]
# (train_remote pid=24176) Figure(1200x500)
# m(train_remote pid=27908)
# (train_remote pid=27908) Figure(1200x500)
# m(train_remote pid=8952)
# (train_remote pid=8952) [mobresnet] Epoch 1/10 [repeated 2x across cluster]
# (train_remote pid=8952)   Train Loss: 0.2996 | Val Loss: 0.7001 [repeated 2x across cluster]
# (train_remote pid=8952)   Train Acc : 0.8937 | Val Acc : 0.7205 [repeated 2x across cluster]
# m(train_remote pid=3340)
# (train_remote pid=8952) Figure(1200x500)
# (train_remote pid=3340) Figure(1200x500)
# m(train_remote pid=8952)
# (train_remote pid=8952) [mobresnet] Epoch 2/10 [repeated 2x across cluster]
# (train_remote pid=8952)   Train Loss: 0.1588 | Val Loss: 0.2961 [repeated 2x across cluster]
# (train_remote pid=8952)   Train Acc : 0.9386 | Val Acc : 0.8735 [repeated 2x across cluster]
# m(train_remote pid=3340)
# (train_remote pid=8952) Figure(1200x500)
# (train_remote pid=3340) Figure(1200x500)
# m(train_remote pid=3340)
# (train_remote pid=3340) [mobresnet] Epoch 3/10 [repeated 2x across cluster]
# (train_remote pid=3340)   Train Loss: 0.1334 | Val Loss: 0.3545 [repeated 2x across cluster]
# (train_remote pid=3340)   Train Acc : 0.9481 | Val Acc : 0.8624 [repeated 2x across cluster]
# m(train_remote pid=8952)
# (train_remote pid=3340) Figure(1200x500)
# (train_remote pid=8952) Figure(1200x500)
# m(train_remote pid=8952)
# (train_remote pid=8952) [mobresnet] Epoch 4/10 [repeated 2x across cluster]
# (train_remote pid=8952)   Train Loss: 0.1003 | Val Loss: 0.1556 [repeated 2x across cluster]
# (train_remote pid=8952)   Train Acc : 0.9608 | Val Acc : 0.9389 [repeated 2x across cluster]
# (train_remote pid=8952) Figure(1200x500)
# m(train_remote pid=3340)
# (train_remote pid=3340) Figure(1200x500)
# m(train_remote pid=8952)
# (train_remote pid=8952) [mobresnet] Epoch 5/10 [repeated 2x across cluster]
# (train_remote pid=8952)   Train Loss: 0.0730 | Val Loss: 0.2304 [repeated 2x across cluster]
# (train_remote pid=8952)   Train Acc : 0.9807 | Val Acc : 0.9167 [repeated 2x across cluster]
# m(train_remote pid=3340)
# (train_remote pid=8952) Figure(1200x500)
# (train_remote pid=3340) Figure(1200x500)
# m(train_remote pid=8952)
# (train_remote pid=8952) [mobresnet] Epoch 6/10 [repeated 2x across cluster]
# (train_remote pid=8952)   Train Loss: 0.0565 | Val Loss: 0.0849 [repeated 2x across cluster]
# (train_remote pid=8952)   Train Acc : 0.9786 | Val Acc : 0.9722 [repeated 2x across cluster]
# m(train_remote pid=3340)
# (train_remote pid=8952) Figure(1200x500)
# (train_remote pid=3340) Figure(1200x500)
# m(train_remote pid=3340)
# (train_remote pid=3340) [mobresnet] Epoch 7/10 [repeated 2x across cluster]
# (train_remote pid=3340)   Train Loss: 0.0392 | Val Loss: 0.0942 [repeated 2x across cluster]
# (train_remote pid=3340)   Train Acc : 0.9857 | Val Acc : 0.9673 [repeated 2x across cluster]
# (train_remote pid=3340) Figure(1200x500)
# m(train_remote pid=8952)
# (train_remote pid=8952) Figure(1200x500)
# m(train_remote pid=3340)
# (train_remote pid=3340) [mobresnet] Epoch 8/10 [repeated 2x across cluster]
# (train_remote pid=3340)   Train Loss: 0.0307 | Val Loss: 0.0920 [repeated 2x across cluster]
# (train_remote pid=3340)   Train Acc : 0.9897 | Val Acc : 0.9735 [repeated 2x across cluster]
# m(train_remote pid=8952)
# (train_remote pid=3340) Figure(1200x500)
# (train_remote pid=8952) Figure(1200x500)
# m(train_remote pid=3340)
# (train_remote pid=3340) [mobresnet] Epoch 9/10 [repeated 2x across cluster]
# (train_remote pid=3340)   Train Loss: 0.0284 | Val Loss: 0.0806 [repeated 2x across cluster]
# (train_remote pid=3340)   Train Acc : 0.9886 | Val Acc : 0.9722 [repeated 2x across cluster]
# (train_remote pid=3340) Figure(1200x500)
# m(train_remote pid=8952)
# (train_remote pid=8952) Figure(1200x500)
# m(train_remote pid=3340)
# (train_remote pid=3340) [mobresnet] Epoch 10/10 [repeated 2x across cluster]
# (train_remote pid=3340)   Train Loss: 0.0194 | Val Loss: 0.0816 [repeated 2x across cluster]
# (train_remote pid=3340)   Train Acc : 0.9939 | Val Acc : 0.9741 [repeated 2x across cluster]
# (train_remote pid=3340) Figure(1200x500)
# m(train_remote pid=8952)
# (train_remote pid=8952) Figure(1200x500)
# m(train_remote pid=21128)
# (train_remote pid=21128) [mobresnet] Epoch 1/10 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Loss: 0.8002 | Val Loss: 0.4167 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Acc : 0.8286 | Val Acc : 0.8538 [repeated 2x across cluster]
# (train_remote pid=21128) Figure(1200x500)
# m(train_remote pid=16732)
# (train_remote pid=16732) Figure(1200x500)
# m(train_remote pid=21128)
# (train_remote pid=21128) [mobresnet] Epoch 2/10 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Loss: 0.2900 | Val Loss: 1.2834 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Acc : 0.9177 | Val Acc : 0.6613 [repeated 2x across cluster]
# (train_remote pid=21128) Figure(1200x500)
# m(train_remote pid=16732)
# (train_remote pid=16732) Figure(1200x500)
# m(train_remote pid=21128)
# (train_remote pid=21128) [mobresnet] Epoch 3/10 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Loss: 0.2157 | Val Loss: 0.9822 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Acc : 0.9376 | Val Acc : 0.7940 [repeated 2x across cluster]
# (train_remote pid=21128) Figure(1200x500)
# m(train_remote pid=16732)
# (train_remote pid=16732) Figure(1200x500)
# m(train_remote pid=21128)
# (train_remote pid=21128) [mobresnet] Epoch 4/10 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Loss: 0.1903 | Val Loss: 0.5304 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Acc : 0.9389 | Val Acc : 0.8100 [repeated 2x across cluster]
# (train_remote pid=21128) Figure(1200x500)
# m(train_remote pid=16732)
# (train_remote pid=16732) Figure(1200x500)
# m(train_remote pid=21128)
# (train_remote pid=21128) [mobresnet] Epoch 5/10 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Loss: 0.1119 | Val Loss: 0.1992 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Acc : 0.9622 | Val Acc : 0.9408 [repeated 2x across cluster]
# (train_remote pid=21128) Figure(1200x500)
# m(train_remote pid=16732)
# (train_remote pid=16732) Figure(1200x500)
# m(train_remote pid=21128)
# (train_remote pid=21128) [mobresnet] Epoch 6/10 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Loss: 0.0975 | Val Loss: 0.1843 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Acc : 0.9643 | Val Acc : 0.9525 [repeated 2x across cluster]
# (train_remote pid=21128) Figure(1200x500)
# m(train_remote pid=16732)
# (train_remote pid=16732) Figure(1200x500)
# m(train_remote pid=21128)
# (train_remote pid=21128) [mobresnet] Epoch 7/10 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Loss: 0.0773 | Val Loss: 0.0983 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Acc : 0.9770 | Val Acc : 0.9673 [repeated 2x across cluster]
# (train_remote pid=21128) Figure(1200x500)
# m(train_remote pid=16732)
# (train_remote pid=16732) Figure(1200x500)
# m(train_remote pid=21128)
# (train_remote pid=21128) [mobresnet] Epoch 8/10 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Loss: 0.0682 | Val Loss: 0.1010 [repeated 2x across cluster]
# (train_remote pid=21128)   Train Acc : 0.9767 | Val Acc : 0.9630 [repeated 2x across cluster]
# (train_remote pid=21128) Figure(1200x500)
# m(train_remote pid=16732)
# (train_remote pid=16732) [mobresnet] Epoch 8/10
# (train_remote pid=16732)   Train Loss: 0.0466 | Val Loss: 0.1033
# (train_remote pid=16732)   Train Acc : 0.9836 | Val Acc : 0.9661
# (train_remote pid=16732) Figure(1200x500)
# (train_remote pid=21128) [mobresnet] Epoch 9/10
# (train_remote pid=21128)   Train Loss: 0.0624 | Val Loss: 0.0912
# (train_remote pid=21128)   Train Acc : 0.9836 | Val Acc : 0.9679
# m(train_remote pid=21128)
# (train_remote pid=21128) Figure(1200x500)
# m(train_remote pid=16732)
# (train_remote pid=16732) [mobresnet] Epoch 9/10
# (train_remote pid=16732)   Train Loss: 0.0322 | Val Loss: 0.0728
# (train_remote pid=16732)   Train Acc : 0.9910 | Val Acc : 0.9716
# (train_remote pid=16732) Figure(1200x500)
# (train_remote pid=21128) [mobresnet] Epoch 10/10
# (train_remote pid=21128)   Train Loss: 0.0398 | Val Loss: 0.0890
# (train_remote pid=21128)   Train Acc : 0.9836 | Val Acc : 0.9698
# m(train_remote pid=21128)
# (train_remote pid=21128) Figure(1200x500)
# m(train_remote pid=16732)
# (train_remote pid=16732) [mobresnet] Epoch 10/10
# (train_remote pid=16732)   Train Loss: 0.0232 | Val Loss: 0.0741
# (train_remote pid=16732)   Train Acc : 0.9931 | Val Acc : 0.9747
# (train_remote pid=16732) Figure(1200x500)
# (train_remote pid=21620) [mobresnet] Epoch 1/10
# (train_remote pid=21620)   Train Loss: 0.2848 | Val Loss: 0.6967
# (train_remote pid=21620)   Train Acc : 0.8952 | Val Acc : 0.6971
# m(train_remote pid=21620)
# (train_remote pid=21620) Figure(1200x500)
# m(train_remote pid=28788)
# (train_remote pid=28788) [mobresnet] Epoch 1/10
# (train_remote pid=28788)   Train Loss: 0.3190 | Val Loss: 0.4020
# (train_remote pid=28788)   Train Acc : 0.8870 | Val Acc : 0.8304
# (train_remote pid=28788) Figure(1200x500)
# (train_remote pid=21620) [mobresnet] Epoch 2/10
# (train_remote pid=21620)   Train Loss: 0.1429 | Val Loss: 0.3491
# (train_remote pid=21620)   Train Acc : 0.9479 | Val Acc : 0.8735
# m(train_remote pid=21620)
# (train_remote pid=21620) Figure(1200x500)
# m(train_remote pid=28788)
# (train_remote pid=28788) [mobresnet] Epoch 2/10
# (train_remote pid=28788)   Train Loss: 0.1662 | Val Loss: 0.6281
# (train_remote pid=28788)   Train Acc : 0.9413 | Val Acc : 0.7563
# (train_remote pid=28788) Figure(1200x500)
# (train_remote pid=21620) [mobresnet] Epoch 3/10
# (train_remote pid=21620)   Train Loss: 0.1031 | Val Loss: 0.4901
# (train_remote pid=21620)   Train Acc : 0.9680 | Val Acc : 0.8168
# m(train_remote pid=21620)
# (train_remote pid=21620) Figure(1200x500)
# m(train_remote pid=28788)
# (train_remote pid=28788) [mobresnet] Epoch 3/10
# (train_remote pid=28788)   Train Loss: 0.1238 | Val Loss: 1.0532
# (train_remote pid=28788)   Train Acc : 0.9561 | Val Acc : 0.6885
# (train_remote pid=28788) Figure(1200x500)
# (train_remote pid=21620) [mobresnet] Epoch 4/10
# (train_remote pid=21620)   Train Loss: 0.1102 | Val Loss: 0.2428
# (train_remote pid=21620)   Train Acc : 0.9598 | Val Acc : 0.9038
# m(train_remote pid=21620)
# (train_remote pid=21620) Figure(1200x500)
# m(train_remote pid=28788)
# (train_remote pid=28788) [mobresnet] Epoch 4/10
# (train_remote pid=28788)   Train Loss: 0.1035 | Val Loss: 0.1384
# (train_remote pid=28788)   Train Acc : 0.9635 | Val Acc : 0.9469
# (train_remote pid=28788) Figure(1200x500)
# (train_remote pid=21620) [mobresnet] Epoch 5/10
# (train_remote pid=21620)   Train Loss: 0.0949 | Val Loss: 0.1308
# (train_remote pid=21620)   Train Acc : 0.9683 | Val Acc : 0.9476
# m(train_remote pid=21620)
# (train_remote pid=21620) Figure(1200x500)
# m(train_remote pid=28788)
# (train_remote pid=28788) [mobresnet] Epoch 5/10
# (train_remote pid=28788)   Train Loss: 0.0780 | Val Loss: 0.1624
# (train_remote pid=28788)   Train Acc : 0.9712 | Val Acc : 0.9463
# (train_remote pid=28788) Figure(1200x500)
# (train_remote pid=21620) [mobresnet] Epoch 6/10
# (train_remote pid=21620)   Train Loss: 0.0677 | Val Loss: 0.1634
# (train_remote pid=21620)   Train Acc : 0.9823 | Val Acc : 0.9383
# m(train_remote pid=21620)
# (train_remote pid=21620) Figure(1200x500)
# m(train_remote pid=28788)
# (train_remote pid=28788) [mobresnet] Epoch 6/10
# (train_remote pid=28788)   Train Loss: 0.0529 | Val Loss: 0.1202
# (train_remote pid=28788)   Train Acc : 0.9847 | Val Acc : 0.9599
# (train_remote pid=28788) Figure(1200x500)
# (train_remote pid=21620) [mobresnet] Epoch 7/10
# (train_remote pid=21620)   Train Loss: 0.0438 | Val Loss: 0.0838
# (train_remote pid=21620)   Train Acc : 0.9831 | Val Acc : 0.9716
# m(train_remote pid=21620)
# (train_remote pid=21620) Figure(1200x500)
# m(train_remote pid=28788)
# (train_remote pid=28788) Figure(1200x500)
# (train_remote pid=28788) [mobresnet] Epoch 7/10
# (train_remote pid=28788)   Train Loss: 0.0425 | Val Loss: 0.0785
# (train_remote pid=28788)   Train Acc : 0.9857 | Val Acc : 0.9729
# (train_remote pid=21620) [mobresnet] Epoch 8/10
# (train_remote pid=21620)   Train Loss: 0.0257 | Val Loss: 0.0829
# (train_remote pid=21620)   Train Acc : 0.9923 | Val Acc : 0.9747
# m(train_remote pid=21620)
# (train_remote pid=21620) Figure(1200x500)
# m(train_remote pid=28788)
# (train_remote pid=28788) Figure(1200x500)
# (train_remote pid=28788) [mobresnet] Epoch 8/10
# (train_remote pid=28788)   Train Loss: 0.0235 | Val Loss: 0.0797
# (train_remote pid=28788)   Train Acc : 0.9942 | Val Acc : 0.9722
# (train_remote pid=21620) [mobresnet] Epoch 9/10
# (train_remote pid=21620)   Train Loss: 0.0277 | Val Loss: 0.0855
# (train_remote pid=21620)   Train Acc : 0.9918 | Val Acc : 0.9735
# m(train_remote pid=21620)
# (train_remote pid=21620) Figure(1200x500)
# m(train_remote pid=28788)
# (train_remote pid=28788) [mobresnet] Epoch 9/10
# (train_remote pid=28788)   Train Loss: 0.0306 | Val Loss: 0.0750
# (train_remote pid=28788)   Train Acc : 0.9926 | Val Acc : 0.9722
# (train_remote pid=28788) Figure(1200x500)
# (train_remote pid=21620) [mobresnet] Epoch 10/10
# (train_remote pid=21620)   Train Loss: 0.0270 | Val Loss: 0.0758
# (train_remote pid=21620)   Train Acc : 0.9929 | Val Acc : 0.9735
# m(train_remote pid=21620)
# (train_remote pid=21620) Figure(1200x500)
# m(train_remote pid=28788)
# (train_remote pid=28788) [mobresnet] Epoch 10/10
# (train_remote pid=28788)   Train Loss: 0.0216 | Val Loss: 0.0729
# (train_remote pid=28788)   Train Acc : 0.9939 | Val Acc : 0.9759
# (train_remote pid=28788) Figure(1200x500)
# (train_remote pid=23444) [mobresnet] Epoch 1/10
# (train_remote pid=23444)   Train Loss: 0.2963 | Val Loss: 0.3270
# (train_remote pid=23444)   Train Acc : 0.8907 | Val Acc : 0.8735
# m(train_remote pid=23444)
# (train_remote pid=23444) Figure(1200x500)
# m(train_remote pid=24752)
# (train_remote pid=24752) Figure(1200x500)
# m(train_remote pid=23444)
# (train_remote pid=23444) [mobresnet] Epoch 2/10 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Loss: 0.1627 | Val Loss: 0.2758 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Acc : 0.9439 | Val Acc : 0.8970 [repeated 2x across cluster]
# (train_remote pid=23444) Figure(1200x500)
# m(train_remote pid=24752)
# (train_remote pid=24752) Figure(1200x500)
# m(train_remote pid=23444)
# (train_remote pid=23444) [mobresnet] Epoch 3/10 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Loss: 0.1313 | Val Loss: 0.5094 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Acc : 0.9566 | Val Acc : 0.8014 [repeated 2x across cluster]
# (train_remote pid=23444) Figure(1200x500)
# m(train_remote pid=24752)
# (train_remote pid=24752) Figure(1200x500)
# m(train_remote pid=23444)
# (train_remote pid=23444) [mobresnet] Epoch 4/10 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Loss: 0.0973 | Val Loss: 0.2811 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Acc : 0.9664 | Val Acc : 0.8859 [repeated 2x across cluster]
# (train_remote pid=23444) Figure(1200x500)
# m(train_remote pid=24752)
# (train_remote pid=24752) Figure(1200x500)
# m(train_remote pid=23444)
# (train_remote pid=23444) [mobresnet] Epoch 5/10 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Loss: 0.0796 | Val Loss: 0.1629 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Acc : 0.9770 | Val Acc : 0.9389 [repeated 2x across cluster]
# (train_remote pid=23444) Figure(1200x500)
# m(train_remote pid=24752)
# (train_remote pid=24752) Figure(1200x500)
# m(train_remote pid=23444)
# (train_remote pid=23444) [mobresnet] Epoch 6/10 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Loss: 0.0536 | Val Loss: 0.0794 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Acc : 0.9817 | Val Acc : 0.9729 [repeated 2x across cluster]
# (train_remote pid=23444) Figure(1200x500)
# m(train_remote pid=24752)
# (train_remote pid=24752) Figure(1200x500)
# m(train_remote pid=23444)
# (train_remote pid=23444) [mobresnet] Epoch 7/10 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Loss: 0.0360 | Val Loss: 0.1530 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Acc : 0.9865 | Val Acc : 0.9537 [repeated 2x across cluster]
# (train_remote pid=23444) Figure(1200x500)
# m(train_remote pid=24752)
# (train_remote pid=24752) Figure(1200x500)
# m(train_remote pid=23444)
# (train_remote pid=23444) [mobresnet] Epoch 8/10 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Loss: 0.0296 | Val Loss: 0.0908 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Acc : 0.9915 | Val Acc : 0.9729 [repeated 2x across cluster]
# (train_remote pid=23444) Figure(1200x500)
# m(train_remote pid=24752)
# (train_remote pid=24752) Figure(1200x500)
# m(train_remote pid=23444)
# (train_remote pid=23444) [mobresnet] Epoch 9/10 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Loss: 0.0223 | Val Loss: 0.0846 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Acc : 0.9942 | Val Acc : 0.9735 [repeated 2x across cluster]
# (train_remote pid=23444) Figure(1200x500)
# m(train_remote pid=24752)
# (train_remote pid=24752) Figure(1200x500)
# m(train_remote pid=23444)
# (train_remote pid=23444) [mobresnet] Epoch 10/10 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Loss: 0.0223 | Val Loss: 0.0838 [repeated 2x across cluster]
# (train_remote pid=23444)   Train Acc : 0.9960 | Val Acc : 0.9747 [repeated 2x across cluster]
# (train_remote pid=23444) Figure(1200x500)
# m(train_remote pid=24752)
# (train_remote pid=24752) [mobresnet] Epoch 10/10
# (train_remote pid=24752)   Train Loss: 0.0260 | Val Loss: 0.0715
# (train_remote pid=24752)   Train Acc : 0.9958 | Val Acc : 0.9784
# (train_remote pid=24752) Figure(1200x500)
# (train_remote pid=12784) [mobresnet] Epoch 1/10
# (train_remote pid=12784)   Train Loss: 0.5081 | Val Loss: 0.5478
# (train_remote pid=12784)   Train Acc : 0.8569 | Val Acc : 0.7428
# m(train_remote pid=12784)
# (train_remote pid=12784) Figure(1200x500)
# m(train_remote pid=24644)
# (train_remote pid=24644) Figure(1200x500)
# m(train_remote pid=12784)
# (train_remote pid=12784) [mobresnet] Epoch 2/10 [repeated 2x across cluster]
# (train_remote pid=12784)   Train Loss: 0.1966 | Val Loss: 0.9508 [repeated 2x across cluster]
# (train_remote pid=12784)   Train Acc : 0.9378 | Val Acc : 0.6706 [repeated 2x across cluster]
# (train_remote pid=12784) Figure(1200x500)
# m(train_remote pid=24644)
# (train_remote pid=24644) Figure(1200x500)
# (train_remote pid=24644) [mobresnet] Epoch 3/10
# (train_remote pid=24644)   Train Loss: 0.1208 | Val Loss: 0.3199
# (train_remote pid=24644)   Train Acc : 0.9563 | Val Acc : 0.8649
# m(train_remote pid=24644)
# (train_remote pid=24644) Figure(1200x500)
# m(train_remote pid=8708)
# (train_remote pid=8708) [mobresnet] Epoch 1/10
# (train_remote pid=8708)   Train Loss: 0.2859 | Val Loss: 0.5214
# (train_remote pid=8708)   Train Acc : 0.8923 | Val Acc : 0.7847
# (train_remote pid=8708) Figure(1200x500)
# (train_remote pid=24644) [mobresnet] Epoch 4/10
# (train_remote pid=24644)   Train Loss: 0.0847 | Val Loss: 0.1977
# (train_remote pid=24644)   Train Acc : 0.9733 | Val Acc : 0.9210
# m(train_remote pid=24644)
# (train_remote pid=24644) Figure(1200x500)
# m(train_remote pid=8708)
# (train_remote pid=8708) [mobresnet] Epoch 2/10
# (train_remote pid=8708)   Train Loss: 0.1587 | Val Loss: 0.4013
# (train_remote pid=8708)   Train Acc : 0.9463 | Val Acc : 0.8532
# (train_remote pid=8708) Figure(1200x500)
# (train_remote pid=24644) [mobresnet] Epoch 5/10
# (train_remote pid=24644)   Train Loss: 0.0514 | Val Loss: 0.1406
# (train_remote pid=24644)   Train Acc : 0.9823 | Val Acc : 0.9445
# m(train_remote pid=24644)
# (train_remote pid=24644) Figure(1200x500)

# %%
def save_row(result, filename):
    # Jadikan DataFrame 1 baris
    df = pd.DataFrame([result])

    # Jika file tidak ada → buat baru dengan header
    if not os.path.exists(filename):
        df.to_csv(filename, index=False)
    else:
        # Jika ada → append tanpa header
        df.to_csv(filename, mode="a", header=False, index=False)

    print(f"Row saved to {filename}")

# %%
from deap import base, creator, tools
import random
import multiprocessing
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()

toolbox.register("lr", random.uniform, LR_MIN, LR_MAX)
toolbox.register("wd", random.uniform, WD_MIN, WD_MAX)
toolbox.register("dp", random.uniform, DP_MIN, DP_MAX)

toolbox.register("individual", tools.initCycle, creator.Individual,
                 (toolbox.lr, toolbox.wd, toolbox.dp), n=1)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxBlend, alpha=0.5)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=0.05, indpb=0.2)
toolbox.register("select", tools.selTournament, tournsize=3)

def evaluate_population(pop, generation):
    futures = []

    for i, ind in enumerate(pop):
        name = f"ga_gen{generation}_ind{i}"
        futures.append(train_remote.remote(ind))

    results = ray.get(futures)

    for ind, fit in zip(pop, results):
        ind.fitness.values = (fit,)

        flat = {
            "generation": generation,
            "learning_rate": ind[0],
            "weight_decay": ind[1],
            "dropout": ind[2],
            "fitness": fit,
        }

        # panggil save_row()
        save_row(flat, "ga_results.csv")


toolbox.register("evaluate", evaluate_population)

def run_ga(n_gen=5, pop_size=10):
    pop = toolbox.population(pop_size)

    for gen in range(n_gen):
        print(f"\n===== GENERATION {gen+1} =====")

        # Evaluasi (parallel GPU)
        evaluate_population(pop, gen)

        # Seleksi
        offspring = toolbox.select(pop, len(pop))
        offspring = list(map(toolbox.clone, offspring))

        # Crossover
        for c1, c2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < 0.9:
                tools.cxBlend(c1, c2, alpha=0.4)

        # Mutasi
        for mutant in offspring:
            if random.random() < 0.2:
                tools.mutGaussian(mutant, mu=0, sigma=0.1, indpb=0.3)

        pop = offspring

        best = tools.selBest(pop, 1)[0]
        print("Best:", best, "Fitness:", best.fitness.values[0])

    result = {
        "accuracy": float(best.fitness.values[0]),
        "best_parameters": best,
    }

    # Simpan ke file JSON
    save_path = "./" + name + "-ga.json"
    with open(save_path, "w") as f:
        json.dump(result, f, indent=4)

    print(f"[GA] Hasil terbaik disimpan di {save_path}")

    return tools.selBest(pop, 1)[0]

# %%
start_time = time.perf_counter()

best_ga = run_ga(n_gen=10, pop_size=6)

end_time = time.perf_counter()
elapsed_time = end_time - start_time
print("Best GA params =", best_ga)
print("Time =", elapsed_time)
# Out:
# ===== GENERATION 1 =====
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Best: [0.04792077080109938, -0.0023629887080827204, 0.30155475178420715] Fitness: 0.9796421961752005
#
# ===== GENERATION 2 =====
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Best: [0.0031350438769153005, 0.000780812630957079, 0.3086201155309566] Fitness: 0.974090067859346
#
# ===== GENERATION 3 =====
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Row saved to ga_results.csv
# Best: [0.0031350438769153005, 0.000780812630957079, 0.30930543591768817] Fitness: 0.9753238741517581
#
# ===== GENERATION 4 =====
# ---------------------------------------------------------------------------
# RayTaskError(RuntimeError)                Traceback (most recent call last)
# Cell In[10], line 3
#       1 start_time = time.perf_counter()
# ----> 3 best_ga = run_ga(n_gen=10, pop_size=6)
#       5 end_time = time.perf_counter()
#       6 elapsed_time = end_time - start_time
#
# Cell In[9], line 54, in run_ga(n_gen, pop_size)
#      51 print(f"\n===== GENERATION {gen+1} =====")
#      53 # Evaluasi (parallel GPU)
# ---> 54 evaluate_population(pop, gen)
#      56 # Seleksi
#      57 offspring = toolbox.select(pop, len(pop))
#
# Cell In[9], line 28, in evaluate_population(pop, generation)
#      25     name = f"ga_gen{generation}_ind{i}"
#      26     futures.append(train_remote.remote(ind))
# ---> 28 results = ray.get(futures)
#      30 for ind, fit in zip(pop, results):
#      31     ind.fitness.values = (fit,)
#
# File ~\anaconda3\envs\torch-gpu\lib\site-packages\ray\_private\auto_init_hook.py:22, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      19 @wraps(fn)
#      20 def auto_init_wrapper(*args, **kwargs):
#      21     auto_init_ray()
# ---> 22     return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\torch-gpu\lib\site-packages\ray\_private\client_mode_hook.py:104, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     102     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     103         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 104 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\torch-gpu\lib\site-packages\ray\_private\worker.py:2972, in get(object_refs, timeout, _tensor_transport)
#    2966 if not isinstance(object_refs, list):
#    2967     raise ValueError(
#    2968         f"Invalid type of object refs, {type(object_refs)}, is given. "
#    2969         "'object_refs' must either be an ObjectRef or a list of ObjectRefs. "
#    2970     )
# -> 2972 values, debugger_breakpoint = worker.get_objects(
#    2973     object_refs, timeout=timeout, _tensor_transport=_tensor_transport
#    2974 )
#    2975 for i, value in enumerate(values):
#    2976     if isinstance(value, RayError):
#    2977         # If the object was lost and it wasn't due to owner death, it may be
#    2978         # because the object store is full and objects needed to be evicted.
#
# File ~\anaconda3\envs\torch-gpu\lib\site-packages\ray\_private\worker.py:1031, in Worker.get_objects(self, object_refs, timeout, return_exceptions, skip_deserialization, _tensor_transport)
#    1029     global_worker.core_worker.log_plasma_usage()
#    1030 if isinstance(value, RayTaskError):
# -> 1031     raise value.as_instanceof_cause()
#    1032 else:
#    1033     raise value
#
# RayTaskError(RuntimeError): ray::train_remote() (pid=12784, ip=127.0.0.1)
#   File "python\\ray\\_raylet.pyx", line 1722, in ray._raylet.execute_task
#   File "C:\Users\Gia\AppData\Local\Temp\ipykernel_27764\1159917213.py", line 23, in train_remote
#   File "C:\Users\Gia\AppData\Local\Temp\ipykernel_27764\3441081241.py", line 23, in train_model
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torch\utils\data\dataloader.py", line 732, in __next__
#     data = self._next_data()
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torch\utils\data\dataloader.py", line 1506, in _next_data
#     return self._process_data(data, worker_id)
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torch\utils\data\dataloader.py", line 1541, in _process_data
#     data.reraise()
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torch\_utils.py", line 769, in reraise
#     raise exception
# RuntimeError: Caught RuntimeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torch\utils\data\_utils\worker.py", line 349, in _worker_loop
#     data = fetcher.fetch(index)  # type: ignore[possibly-undefined]
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torch\utils\data\_utils\fetch.py", line 50, in fetch
#     data = self.dataset.__getitems__(possibly_batched_index)
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torch\utils\data\dataset.py", line 416, in __getitems__
#     return [self.dataset[self.indices[idx]] for idx in indices]
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torch\utils\data\dataset.py", line 416, in <listcomp>
#     return [self.dataset[self.indices[idx]] for idx in indices]
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torchvision\datasets\folder.py", line 247, in __getitem__
#     sample = self.transform(sample)
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torchvision\transforms\transforms.py", line 95, in __call__
#     img = t(img)
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torchvision\transforms\transforms.py", line 137, in __call__
#     return F.to_tensor(pic)
#   File "C:\Users\Gia\anaconda3\envs\torch-gpu\lib\site-packages\torchvision\transforms\functional.py", line 176, in to_tensor
#     return img.to(dtype=default_float_dtype).div(255)
# RuntimeError: [enforce fail at alloc_cpu.cpp:121] data. DefaultCPUAllocator: not enough memory: you tried to allocate 602112 bytes.
